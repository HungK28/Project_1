# %%
#Question 6: Did business-owners of a particular race/ethnicity get more loans? 
# If yes, is it statistiscally significant?

# %%
#Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress
from scipy import stats
import json

# %%
california_ppp_path = "../Resources/California_PPP.csv"

ppp_data = pd.read_csv(california_ppp_path)

ppp_data.head()
# Out:
#    LoanNumber DateApproved ProcessingMethod                 BorrowerName  \
# 0  1048448901   04/24/2021              PPP             HUMANGOOD NORCAL
# 1  1122827105   04/09/2020              PPP             ITO INCORPORATED
# 2  1187837109   04/10/2020              PPP      HAVEN HEALTH GROUP, LLC
# 3  1321898800   04/10/2021              PPP  NORTH EAST MEDICAL SERVICES
# 4  1322998906   04/24/2021              PPP              PACIFIC CLINICS
#
#                    BorrowerAddress  BorrowerCity BorrowerState BorrowerZip  \
# 0  6120 Stoneridge Mall Rd Ste 300    Pleasanton            CA  94588-3298
# 1                     431 ISIS AVE     INGLEWOOD            CA  90301-2009
# 2         31752 COAST HWY, STE 300  LAGUNA BEACH            CA  92651-6782
# 3         2171 Junipero Serra Blvd     Daly City            CA  94014-1906
# 4            800 S Santa Anita Ave       Arcadia            CA  91006-3536
#
#    CurrentApprovalAmount RuralUrbanIndicator  ... JobsReported NAICSCode  \
# 0             10000000.0                   U  ...        500.0  623311.0
# 1             10000000.0                   U  ...        500.0  722310.0
# 2             10000000.0                   U  ...        500.0  623110.0
# 3             10000000.0                   U  ...        205.0  621498.0
# 4             10000000.0                   U  ...        103.0  621420.0
#
#          Race  PAYROLL_PROCEED                     BusinessType  \
# 0       White        9999998.0              Sole Proprietorship
# 1       Asian        9361000.0         Subchapter S Corporation
# 2       White       10000000.0  Limited  Liability Company(LLC)
# 3  Unanswered       10000000.0             501(c)3 – Non Profit
# 4       White        9999996.0          Non-Profit Organization
#
#                                OriginatingLender  OriginatingLenderCity  \
# 0  Washington Federal Bank, National Association                SEATTLE
# 1                             City National Bank            LOS ANGELES
# 2                                 East West Bank               PASADENA
# 3                                 East West Bank               PASADENA
# 4                                 East West Bank               PASADENA
#
#   OriginatingLenderState        Gender      Veteran
# 0                     WA  Female Owned  Non-Veteran
# 1                     CA    Male Owned  Non-Veteran
# 2                     CA    Male Owned  Non-Veteran
# 3                     CA    Unanswered   Unanswered
# 4                     CA    Male Owned      Veteran
#
# [5 rows x 23 columns]

# %%
ethnicity_count = ppp_data["Race"].value_counts()
ethnicity_percentage=ethnicity_count/ppp_data["Race"].count() * 100
ethnicity_summary_df=pd.DataFrame({"Total Count": ethnicity_count,
                                   "Percentage of Ethnicities": ethnicity_percentage})
ethnicity_summary_df["Percentage of Ethnicities"]=ethnicity_summary_df["Percentage of Ethnicities"].map("{0:.2f}%".format)
ethnicity_summary_df
# Out:
#                                            Total Count  \
# Unanswered                                      996716
# White                                           154152
# Asian                                            83281
# Black or African American                        60352
# American Indian or Alaska Native                  4644
# Native Hawaiian or Other Pacific Islander         3058
# Multi Group                                         27
# Puerto Rican                                        11
#
#                                           Percentage of Ethnicities
# Unanswered                                                   76.54%
# White                                                        11.84%
# Asian                                                         6.40%
# Black or African American                                     4.63%
# American Indian or Alaska Native                              0.36%
# Native Hawaiian or Other Pacific Islander                     0.23%
# Multi Group                                                   0.00%
# Puerto Rican                                                  0.00%

# %%
# Out:
# Index(['Total Count', 'Percentage of Ethnicities'], dtype='object')

# %%
#boxplot
ppp_data.boxplot("CurrentApprovalAmount", by="Race", figsize=(20,10))
# Out:
# <AxesSubplot:title={'center':'CurrentApprovalAmount'}, xlabel='Race'>

# %%
group1 = ppp_data[ppp_data["Race"] == "American Indian or Alaska Native"]["CurrentApprovalAmount"]
group2 = ppp_data[ppp_data["Race"] == "Asian"]["CurrentApprovalAmount"]
group3 = ppp_data[ppp_data["Race"] == "Black or African American"]["CurrentApprovalAmount"]
group4 = ppp_data[ppp_data["Race"] == "Multi Group"]["CurrentApprovalAmount"]
group5 = ppp_data[ppp_data["Race"] == "Native Hawaiian or Other Pacific Islander"]["CurrentApprovalAmount"]
group6 = ppp_data[ppp_data["Race"] == "Puerto Rican"]["CurrentApprovalAmount"]
group7 = ppp_data[ppp_data["Race"] == "Unanswered"]["CurrentApprovalAmount"]
group8 = ppp_data[ppp_data["Race"] == "White"]["CurrentApprovalAmount"]

# %%
#Stat Summary
stat_summary = ppp_data.groupby(["Race"])[["CurrentApprovalAmount"]].agg(['mean','median','var','std','sem'])
stat_summary
# Out:
#                                           CurrentApprovalAmount            \
#                                                            mean    median
# Race
# American Indian or Alaska Native                   63148.802944  20351.00
# Asian                                              68533.217920  24058.00
# Black or African American                          25202.523321  20377.75
# Multi Group                                       174341.129630  41995.00
# Native Hawaiian or Other Pacific Islander          39854.546593  20415.00
# Puerto Rican                                       68317.409091  14247.50
# Unanswered                                         81069.814366  20832.50
# White                                             100033.200020  20957.00
#
#                                                                         \
#                                                     var            std
# Race
# American Indian or Alaska Native           6.301558e+10  251029.044450
# Asian                                      3.479062e+10  186522.426152
# Black or African American                  6.397136e+09   79982.095030
# Multi Group                                3.010817e+11  548709.098843
# Native Hawaiian or Other Pacific Islander  8.380929e+09   91547.414125
# Puerto Rican                               1.507517e+10  122780.963998
# Unanswered                                 8.269661e+10  287570.180121
# White                                      8.738311e+10  295606.341881
#
#
#                                                      sem
# Race
# American Indian or Alaska Native             3683.645828
# Asian                                         646.335619
# Black or African American                     325.571921
# Multi Group                                105599.115308
# Native Hawaiian or Other Pacific Islander    1655.492971
# Puerto Rican                                37019.853544
# Unanswered                                    288.043537
# White                                         752.903239

# %%
#Stat Summary
jobs_stat_summary = ppp_data.groupby(["Race"])[["JobsReported"]].agg(['mean','median','var','std','sem'])
jobs_stat_summary
# Out:
#                                           JobsReported                      \
#                                                   mean median          var
# Race
# American Indian or Alaska Native              7.260336    1.0   587.444810
# Asian                                         9.789220    4.0   637.991450
# Black or African American                     2.372929    1.0   131.024266
# Multi Group                                  19.481481    5.0  3542.643875
# Native Hawaiian or Other Pacific Islander     6.033682    1.0   639.000174
# Puerto Rican                                  4.000000    1.0    41.200000
# Unanswered                                    8.797630    2.0   781.658992
# White                                        10.449589    2.0   860.924550
#
#
#                                                  std        sem
# Race
# American Indian or Alaska Native           24.237261   0.355662
# Asian                                      25.258493   0.087525
# Black or African American                  11.446583   0.046594
# Multi Group                                59.520113  11.454651
# Native Hawaiian or Other Pacific Islander  25.278453   0.457122
# Puerto Rican                                6.418723   1.935318
# Unanswered                                 27.958165   0.028004
# White                                      29.341516   0.074732

# %%
#ANOVA
stats.f_oneway(group1,group2,group3,group4,group5,group6,group7,group8)
# Out:
# F_onewayResult(statistic=489.0787582634207, pvalue=0.0)

# %%
#T-Test with White and Asian businesses
stats.ttest_ind(group8,group2,equal_var=False)
# Out:
# Ttest_indResult(statistic=31.74515998101095, pvalue=1.1055353492592183e-220)

# %%
#T-Test with Asian and Black businesses
stats.ttest_ind(group3,group2,equal_var=False)
# Out:
# Ttest_indResult(statistic=-59.87354273381556, pvalue=0.0)

# %%
#PPP
ppp_df = ppp_data.loc[ppp_data["ProcessingMethod"] == "PPP",:]

# %%
race_ppp_count = ppp_df["Race"].value_counts()
race_ppp_percentage=race_ppp_count/ppp_df["Race"].count() * 100
race_ppp_summary_df=pd.DataFrame({"Total Count": race_ppp_count,
                                   "Percentage of Ethnicities": race_ppp_percentage})
race_ppp_summary_df["Percentage of Ethnicities"]=race_ppp_summary_df["Percentage of Ethnicities"].map("{0:.2f}%".format)
race_ppp_summary_df
# Out:
#                                            Total Count  \
# Unanswered                                      734160
# White                                           101898
# Black or African American                        53148
# Asian                                            51928
# American Indian or Alaska Native                  3372
# Native Hawaiian or Other Pacific Islander         2374
# Multi Group                                         20
# Puerto Rican                                         7
#
#                                           Percentage of Ethnicities
# Unanswered                                                   77.53%
# White                                                        10.76%
# Black or African American                                     5.61%
# Asian                                                         5.48%
# American Indian or Alaska Native                              0.36%
# Native Hawaiian or Other Pacific Islander                     0.25%
# Multi Group                                                   0.00%
# Puerto Rican                                                  0.00%

# %%
race_ppp_summary_df.columns
# Out:
# Index(['Total Count', 'Percentage of Ethnicities'], dtype='object')

# %%
# boxplot
ppp_df.boxplot("CurrentApprovalAmount", by="Race", figsize=(20,10))
# Out:
# <AxesSubplot:title={'center':'CurrentApprovalAmount'}, xlabel='Race'>

# %%
#ANOVA
group1 = ppp_df[ppp_df["Race"] == "American Indian or Alaska Native"]["CurrentApprovalAmount"]
group2 = ppp_df[ppp_df["Race"] == "Asian"]["CurrentApprovalAmount"]
group3 = ppp_df[ppp_df["Race"] == "Black or African American"]["CurrentApprovalAmount"]
group4 = ppp_df[ppp_df["Race"] == "Multi Group"]["CurrentApprovalAmount"]
group5 = ppp_df[ppp_df["Race"] == "Native Hawaiian or Other Pacific Islander"]["CurrentApprovalAmount"]
group6 = ppp_df[ppp_df["Race"] == "Puerto Rican"]["CurrentApprovalAmount"]
group7 = ppp_df[ppp_df["Race"] == "Unanswered"]["CurrentApprovalAmount"]
group8 = ppp_df[ppp_df["Race"] == "White"]["CurrentApprovalAmount"]

# %%
#Stat Summary
stat_summary = ppp_df.groupby(["Race"])[["CurrentApprovalAmount"]].agg(['mean','median','var','std','sem'])
stat_summary.drop(index="Unanswered",inplace=True)
stat_summary
# Out:
#                                           CurrentApprovalAmount           \
#                                                            mean   median
# Race
# American Indian or Alaska Native                   56916.692364  18684.5
# Asian                                              65242.057261  20833.0
# Black or African American                          22583.140304  20312.0
# Multi Group                                       223578.550000  47622.5
# Native Hawaiian or Other Pacific Islander          34632.503576  19740.5
# Puerto Rican                                       55588.071429  13450.0
# White                                              99394.734056  20832.0
#
#                                                                         \
#                                                     var            std
# Race
# American Indian or Alaska Native           7.265991e+10  269555.022147
# Asian                                      4.236513e+10  205827.915412
# Black or African American                  5.238430e+09   72377.002255
# Multi Group                                4.020011e+11  634035.590175
# Native Hawaiian or Other Pacific Islander  8.579465e+09   92625.400911
# Puerto Rican                               1.358030e+10  116534.526503
# White                                      1.091277e+11  330344.759527
#
#
#                                                      sem
# Race
# American Indian or Alaska Native             4641.984059
# Asian                                         903.240656
# Black or African American                     313.947572
# Multi Group                                141774.667979
# Native Hawaiian or Other Pacific Islander    1901.033383
# Puerto Rican                                44045.910897
# White                                        1034.867127

# %%
#Stat Summary with employee number
jobs_stat_summary = ppp_df.groupby(["Race"])[["JobsReported"]].agg(['mean','median','var','std','sem'])
jobs_stat_summary
# Out:
#                                           JobsReported                      \
#                                                   mean median          var
# Race
# American Indian or Alaska Native              6.594009    1.0   636.054346
# Asian                                         9.920448    3.0   758.970446
# Black or African American                     2.007357    1.0   109.543156
# Multi Group                                  25.000000    7.5  4722.526316
# Native Hawaiian or Other Pacific Islander     5.588880    1.0   774.194162
# Puerto Rican                                  4.285714    1.0    61.571429
# Unanswered                                    9.043713    2.0   913.650007
# White                                        10.656441    2.0  1063.351999
#
#
#                                                  std        sem
# Race
# American Indian or Alaska Native           25.220118   0.434314
# Asian                                      27.549418   0.120896
# Black or African American                  10.466287   0.045399
# Multi Group                                68.720640  15.366402
# Native Hawaiian or Other Pacific Islander  27.824345   0.571064
# Puerto Rican                                7.846746   2.965791
# Unanswered                                 30.226644   0.035277
# White                                      32.609078   0.102154

# %%
stats.f_oneway(group1,group2,group3,group4,group5,group6,group7,group8)
# Out:
# F_onewayResult(statistic=365.2091348134934, pvalue=0.0)

# %%
#T-Test
stats.ttest_ind(group8,group2,equal_var=False)
# Out:
# Ttest_indResult(statistic=24.863516095194747, pvalue=3.525146180548329e-136)

# %%
#PPS
pps_df = ppp_data.loc[ppp_data["ProcessingMethod"] == "PPS",:]

# %%
race_pps_count = pps_df["Race"].value_counts()
race_pps_percentage=race_pps_count/pps_df["Race"].count() * 100
race_pps_summary_df=pd.DataFrame({"Total Count": race_pps_count,
                                   "Percentage of Ethnicities": race_pps_percentage})
race_pps_summary_df["Percentage of Ethnicities"]=race_pps_summary_df["Percentage of Ethnicities"].map("{0:.2f}%".format)
race_pps_summary_df
# Out:
#                                            Total Count  \
# Unanswered                                      262556
# White                                            52254
# Asian                                            31353
# Black or African American                         7204
# American Indian or Alaska Native                  1272
# Native Hawaiian or Other Pacific Islander          684
# Multi Group                                          7
# Puerto Rican                                         4
#
#                                           Percentage of Ethnicities
# Unanswered                                                   73.89%
# White                                                        14.71%
# Asian                                                         8.82%
# Black or African American                                     2.03%
# American Indian or Alaska Native                              0.36%
# Native Hawaiian or Other Pacific Islander                     0.19%
# Multi Group                                                   0.00%
# Puerto Rican                                                  0.00%

# %%
# boxplot
pps_df.boxplot("CurrentApprovalAmount", by="Race", figsize=(20,10))
# Out:
# <AxesSubplot:title={'center':'CurrentApprovalAmount'}, xlabel='Race'>

# %%
#ANOVA
group1 = pps_df[pps_df["Race"] == "American Indian or Alaska Native"]["CurrentApprovalAmount"]
group2 = pps_df[pps_df["Race"] == "Asian"]["CurrentApprovalAmount"]
group3 = pps_df[pps_df["Race"] == "Black or African American"]["CurrentApprovalAmount"]
group4 = pps_df[pps_df["Race"] == "Multi Group"]["CurrentApprovalAmount"]
group5 = pps_df[pps_df["Race"] == "Native Hawaiian or Other Pacific Islander"]["CurrentApprovalAmount"]
group6 = pps_df[pps_df["Race"] == "Puerto Rican"]["CurrentApprovalAmount"]
group7 = pps_df[pps_df["Race"] == "Unanswered"]["CurrentApprovalAmount"]
group8 = pps_df[pps_df["Race"] == "White"]["CurrentApprovalAmount"]

# %%
#Stat Summary
stat_summary = pps_df.groupby(["Race"])[["CurrentApprovalAmount"]].agg(['mean','median','var','std','sem'])
stat_summary
# Out:
#                                           CurrentApprovalAmount            \
#                                                            mean    median
# Race
# American Indian or Alaska Native                   79669.775330  24365.32
# Asian                                              73984.160117  31524.00
# Black or African American                          44527.199695  20832.00
# Multi Group                                        33662.785714  35832.00
# Native Hawaiian or Other Pacific Islander          57979.005833  26250.00
# Puerto Rican                                       90593.750000  20400.00
# Unanswered                                         79266.708656  20833.00
# White                                             101278.241639  32800.00
#
#                                                                         \
#                                                     var            std
# Race
# American Indian or Alaska Native           3.710986e+10  192639.208839
# Asian                                      2.219872e+10  148992.347270
# Black or African American                  1.452335e+10  120512.880296
# Multi Group                                5.138075e+08   22667.322235
# Native Hawaiian or Other Pacific Islander  7.279649e+09   85320.858832
# Puerto Rican                               2.205023e+10  148493.189833
# Unanswered                                 3.736851e+10  193309.369512
# White                                      4.497904e+10  212082.633974
#
#
#                                                     sem
# Race
# American Indian or Alaska Native            5401.335205
# Asian                                        841.442436
# Black or African American                   1419.863563
# Multi Group                                 8567.442503
# Native Hawaiian or Other Pacific Islander   3262.324574
# Puerto Rican                               74246.594917
# Unanswered                                   377.261017
# White                                        927.780709

# %%
#Stat Summary with employee number
jobs_stat_summary = pps_df.groupby(["Race"])[["JobsReported"]].agg(['mean','median','var','std','sem'])
jobs_stat_summary
# Out:
#                                           JobsReported                     \
#                                                   mean median         var
# Race
# American Indian or Alaska Native              9.026730    3.0  454.682212
# Asian                                         9.571875    5.0  437.563609
# Black or African American                     5.069961    1.0  281.278737
# Multi Group                                   3.714286    3.0    5.238095
# Native Hawaiian or Other Pacific Islander     7.577485    4.0  167.146257
# Puerto Rican                                  3.500000    2.0   13.666667
# Unanswered                                    8.109535    2.0  411.944525
# White                                        10.046217    4.0  465.947207
#
#
#                                                  std       sem
# Race
# American Indian or Alaska Native           21.323279  0.597875
# Asian                                      20.918021  0.118136
# Black or African American                  16.771367  0.197598
# Multi Group                                 2.288689  0.865043
# Native Hawaiian or Other Pacific Islander  12.928506  0.494334
# Puerto Rican                                3.696846  1.848423
# Unanswered                                 20.296417  0.039610
# White                                      21.585810  0.094430

# %%
stats.f_oneway(group1,group2,group3,group4,group5,group6,group7,group8)
# Out:
# F_onewayResult(statistic=131.64841936847142, pvalue=1.9323975286134037e-194)

# %%
#T-Test with American Indian and Asian Businesses
stats.ttest_ind(group1,group2,equal_var=False)
# Out:
# Ttest_indResult(statistic=1.0400863166675733, pvalue=0.29848835274998886)

# %%
#T-Test with Unanswered Group and White Businesses
stats.ttest_ind(group8,group7, equal_var=False)
# Out:
# Ttest_indResult(statistic=21.977462258776047, pvalue=1.0808792011116843e-106)
